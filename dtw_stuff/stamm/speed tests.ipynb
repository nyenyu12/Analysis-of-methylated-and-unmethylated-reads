# %%
import fastdtw_numba as fdn
import fastdtw as fdc 
import t_fastdtw as fdp
import test_arrays
import numpy as np
import matplotlib.pyplot as plt

# %%
test_arrays.plot_X_train()

# %%
test_arrays.plot_series()

# %%
from test_arrays import series
long_array1=np.sin(np.linspace(0,100,1000))
long_array2=np.cos(np.linspace(0,100,1000))

# %%
plt.plot(range(series.shape[1]),series[0])
plt.plot(range(series.shape[1]),series[1])
plt.show()

# %%
plt.plot(range(long_array1.shape[0]),long_array1)
plt.plot(range(long_array2.shape[0]),long_array2)
plt.show()

# %%
# %timeit fdn.fastdtw(series[0],series[-1])
# Out:
# 160 ms ± 6.8 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %timeit fdc.fastdtw(series[0],series[-1])
# Out:
# /home/nyenyu/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   """Entry point for launching an IPython kernel.
# 1.38 ms ± 14.9 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
# %timeit fdn.fastdtw(long_array1,long_array2)
# Out:
# 18.5 ms ± 365 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %timeit fdc.fastdtw(long_array1,long_array2)
# Out:
# /home/nyenyu/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   """Entry point for launching an IPython kernel.
# 651 µs ± 13.1 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
# %timeit fdp.fastdtw(long_array1,long_array2)
# Out:
# 69.1 ms ± 1.34 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
