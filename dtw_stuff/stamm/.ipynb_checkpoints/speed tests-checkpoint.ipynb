# %%
import fastdtw_numba as fdn
import fastdtw as fdc 
import t_fastdtw as fdp
import test_arrays
import numpy as np
import matplotlib.pyplot as plt

# %%
test_arrays.plot_X_train()

# %%
test_arrays.plot_series()

# %%
from test_arrays import series
long_array1=np.sin(np.linspace(0,100,100))
long_array2=np.cos(np.linspace(0,100,100))

# %%
# %timeit fdn.fastdtw(series[0],series[-1])
# Out:
# 185 ms ± 24 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %timeit fdc.fastdtw(series[0],series[-1])
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:257: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
# 1.9 ms ± 187 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %timeit fdn.fastdtw(long_array1,long_array2)
# Out:
# 1.22 ms ± 89.7 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
# %timeit fdc.fastdtw(long_array1,long_array2)
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:257: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
# 331 µs ± 47.9 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
